# %%
#install suds 
#Suds is a lightweight SOAP python client that provides a service proxy for Web Services.
# !pip install suds
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting suds
#   Downloading suds-1.1.2-py3-none-any.whl (144 kB)
#      |████████████████████████████████| 144 kB 5.2 MB/s
# Installing collected packages: suds
# Successfully installed suds-1.1.2

# %%
from suds.client import Client

# %%
#connect to widl using required authentification
#to do create python environment to hide password and username
url = 'https://www.swissreg.ch/services11/SwissregWebService?wsdl'
client = Client(url, username='legalmarque', password='dvMXQsUzcIXEZMdAD6Ls')

# %%
#obtain all the WSDL functions
print(client)
# Out:
# Suds ( https://fedorahosted.org/suds/ )  version: 1.1.2
#
# Service ( SwissregWebServiceService ) tns="https://www.swissreg.ch/services"
#    Prefixes (1)
#       ns0 = "http://exception.srwebservice11.ige.ch"
#    Ports (1):
#       (SwissregWebService)
#          Methods (4):
#             getDomainXML(xs:string ipRight)
#             getIpRightXML(xs:string ipRight, xs:string keys)
#             searchIpRight(xs:string ipRight, xs:string queryString)
#             searchModifiedIpRight(xs:string ipRight, xs:dateTime fromDateTime, xs:dateTime toDateTime)
#          Types (7):
#             ns0:EmptyResultException
#             ns0:ExceededKeyLimitException
#             ns0:InvalidDateRangeException
#             ns0:InvalidIpRightException
#             ns0:InvalidKeyFormatException
#             ns0:InvalidQueryStringException
#             ns0:SwissregServiceException

# %%
#search by query name according to documentation
Ip_Right = client.service.searchIpRight("CH-TM", 'tmText' '=''apple')

# %%
Ip_Right
# Out:
# 55717/2011,61817/2017,56140/2013,64589/2015,61330/2015,05270/1997,77758/2018,77494/2018,00266/2006,59377/2015,64411/2017,06044/1996,50001/2014,55129/2015,07450/1985,02118/1992,04968/1988,63428/2015,60831/2017,62266/2017,01322/2019,57319/2015,05028/1991,56046/2016,04297/1999,06348/1992,08179/1986,00754/1989,12188/2000,56438/2007,02119/1992,64779/2015,63394/2016,51594/2016,54853/2016,51792/2015,62661/2017,57938/2017,75504/2018,61601/2013,19180/2021,07257/1986,56329/2013,07738/1988,51955/2016,65217/2015,50679/2011,13120/2021,09249/2022,05676/1991,06362/1993,59362/2016,61343/2017,57390/2016,07445/2021,03684/1992,08238/1988,07233/1996,00001/1985,07152/1988,64334/2015,63486/2015,57561/2015,64332/2015,59900/2016,64777/2015,09522/2019,56917/2015,57089/2014,08045/2001,06849/2000,09324/2000,12618/1995,07232/1996,61818/2017,53577/2016,65037/2014,61843/2017,52790/2015,60836/2017,51046/2014,60597/2014,03927/2019,04941/1999,61365/2006,02900/2003,63714/2014,51981/2016,50953/2015,59424/2014,65129/2015,64339/2015,52018/2018,59927/2014,09526/2019,52704/2011,09221/2022

# %%
#save query result in csv format
with open('ip_right.csv', 'w') as f:
    f.write(Ip_Right)

# %%
#to do search result total

# %%
#ascertain if result is same as IPI register
Ipi_Ip_Right = list(Ip_Right.split(','))
len(Ipi_Ip_Right)
# Out:
# 97

# %%
#use query result as input to generate both trademark & bname xml
response = client.service.getIpRightXML("CH-TM", Ip_Right)

# %%
response

# %%
#save query response as xml
with open('response.xml', 'w') as f:
    f.write(response)

# %%
#to do ---> expiration date and basregn

# %%
def retrieve_marque_data(transac):
    """"""
    
    basipikey = transac.find("basipikey").text
    origlan = transac.find("origlan").text
    basappn = transac.find("basappn").text
    basregn = transac.find("basregn").text if transac.find("basregn") is not None else None

    basannd = transac.find("basannd").text
    basstate = transac.find("basstate").text

    basregper = transac.find("basregper").text
    expirationdate = transac.find("expirationdate").text

    marpicn = transac.find("marpicn").text
    
#     print(f"Marque verbale: {markve}")
    
    # Classes
    gsgr = transac.find("gsgr")
    intreggs = gsgr.findall("intregg")

    classes = []

    for intregg in intreggs:
        
        nicclai = intregg.find("nicclai").text
        
        classes.append(int(nicclai))

    # Class description
    gstermt = gsgr.find("gstermt").text

    regadrs = transac.findall("regadr")
    
    # TODO check format of mandataire/titulaire
    titulaire_name = None
    titulaire_addrl = None
    titulaire_plainco = None
    titulaire_nat = None

    mandataire_namel = None
    mandataire_addrl = None
    mandataire_plainco = None
    mandataire_nat = None
    
    # Addresses
    for regadr in regadrs:
        
        addrrole = regadr.find("addrrole").text
        nameadd = regadr.find("nameadd")
        
        namel = nameadd.find("namel").text if nameadd.find("namel") is not None else None
        addrl = nameadd.find("addrl").text if nameadd.find("addrl") is not None else None
        
        plainco = nameadd.find("plainco").text
        nat = nameadd.find("nat").text
        
        # 1: titulaire
        if int(addrrole) == 1:
            titulaire_name = namel
            titulaire_addrl = addrl
            titulaire_plainco = plainco
            titulaire_nat = nat
        
        # 3: mandataire
        elif int(addrrole) == 3:
            mandataire_namel = namel
            mandataire_addrl = addrl
            mandataire_plainco = plainco
            mandataire_nat = nat
        
    # TODO verify what oppositiongr and oppositionstate mean
    oppositiongr = transac.find("oppositiongr")
    oppositionstate = oppositiongr.find("oppositionstate")

    martype = transac.find("martype").text
    
    # TODO: oppositiongr
    row = [basipikey, origlan, basappn,basregn, basannd, basstate,marpicn, basregper, expirationdate,
           classes, gstermt, 
           titulaire_name,
           titulaire_addrl,
           titulaire_plainco,
           titulaire_nat,
           mandataire_namel, 
           mandataire_addrl,
           mandataire_plainco,
           mandataire_nat,
           martype]
    
    return row

# %%
def parse_xml(xml_file):
    import xml.etree.ElementTree as et 
    
    rows = []
    
    # Parse file
    xtree = et.parse(xml_file)
    xroot = xtree.getroot()

    for node in xroot:
        if node.tag == 'transac':
            for transac in node:
                if transac.tag == 'marinfo':
                    # Marques verbales
                    marpicn = transac.find("marpicn")
                    if marpicn is not None:
                        row = retrieve_marque_data(transac)
                        rows.append(row)
    return rows

# %%
#Use function to parse xml file and save in tables
tables = []
rows = parse_xml("/content/response.xml")
tables.extend(rows)

# %%
#generate dataframe using pandas with column names
import pandas as pd

#Display classes in ET module
columns=['basipikey', 'origlan', 'basappn','basregn', 'basannd', 'basstate', 'marpicn', 'basregper','expirationdate',
           'classes', 'gstermt',
           'titulaire_name',
           'titulaire_addrl',
           'titulaire_plainco',
           'titulaire_nat',
           'mandataire_namel', 
           'mandataire_addrl',
           'mandataire_plainco',
           'mandataire_nat',
           'martype']

# %%
df = pd.DataFrame(tables, columns=columns)

# %%
df.head()
# Out:
#     basipikey origlan     basappn    basregn     basannd basstate  \
# 0  1200061458      de  05270/1997   P-449475  1998-01-16        1
# 1  1204524163      de  55129/2015       None  2015-04-29        0
# 2  1100343807      de  07450/1985  2P-343807  1985-12-05        1
# 3  1205989023      fr  01322/2019     732952  2019-06-27        1
# 4  1200001111      de  05028/1991   P-393027  1991-07-23        1
#
#                                              marpicn basregper expirationdate  \
# 0  https://www.swissreg.ch/srclient/images/loadIm...        20     2018-01-16
# 1  https://www.swissreg.ch/srclient/images/loadIm...        10     2025-04-29
# 2  https://www.swissreg.ch/srclient/images/loadIm...        40     2025-12-05
# 3  https://www.swissreg.ch/srclient/images/loadIm...        10     2029-06-27
# 4  https://www.swissreg.ch/srclient/images/loadIm...        30     2021-07-23
#
#             classes                                            gstermt  \
# 0              [33]         33 Apfelliköre schweizerischer Herkunft.\n
# 1          [32, 33]  32 Alkoholfreie Apfelgetränke, alkoholfreier A...
# 2              [14]  Montres et leurs parties.                     ...
# 3      [35, 37, 39]  35 Location de distributeurs automatiques.\n37...
# 4  [14, 16, 25, 28]  Schmuckwaren, Uhren und Armbanduhren. Druckere...
#
#                                     titulaire_name           titulaire_addrl  \
# 0                   DIWISA Distillerie Willisau SA       Menznauerstrasse 23
# 1                            Emil Ebneter & Co. AG        Weissbadstrasse 27
# 2                                       APPLE INC.           1 Infinite Loop
# 3                       Apple Fresh / Individuelle  Chemin de pré-dessous 2a
# 4  McDonald's International Property Company, Ltd.   110 N. Carpenter Street
#
#          titulaire_plainco titulaire_nat            mandataire_namel  \
# 0            6130 Willisau            CH                        None
# 1           9050 Appenzell            CH             Phaenomina GmbH
# 2      Cupertino, CA 95014            US            Lenz & Staehelin
# 3          1131 Tolochenaz            CH  Polat Safak / Individuelle
# 4  Chicago, Illinois 60607            US       Isler & Pedrazzini AG
#
#            mandataire_addrl mandataire_plainco mandataire_nat martype
# 0                      None               None           None       3
# 1         Grundstrasse 60 B         8712 Stäfa             CH       3
# 2    Brandschenkestrasse 24        8027 Zürich             CH       3
# 3  Chemin de pré-dessous 2a    1131 Tolochenaz             CH       3
# 4                  Postfach        8027 Zürich             CH       3

# %% [markdown]
# #merge and rename columns

# %%
df['titulaire'] = df[['titulaire_name', 'titulaire_addrl', 'titulaire_plainco', 'titulaire_nat']].apply(lambda x: ' '.join(x), axis=1)

# %%
df['mandataire'] = df.mandataire_namel.fillna('') + ' ' + df.mandataire_addrl.fillna('') + ' ' + df.mandataire_plainco.fillna('') + ' ' + df.mandataire_nat.fillna('')

# %%
#old,new
df.rename(columns = {'classes':'Classes de Nice', 'basappn':'No de la demande', 'basregn':'No de la marque','basannd':'Dépôt', 'expirationdate':'Échéance de la protection', 'marpicn':'marque' }, inplace = True)

# %% [markdown]
# #columns to drop

# %%
#drop unused columns 
df.drop(['titulaire_name','titulaire_addrl','titulaire_plainco','titulaire_nat', 'mandataire_namel', 'mandataire_addrl', 'mandataire_plainco', 'mandataire_nat', 'gstermt'], axis=1, inplace=True)

# %%
df.head()
# Out:
#     basipikey origlan No de la demande No de la marque       Dépôt basstate  \
# 0  1200061458      de       05270/1997        P-449475  1998-01-16        1
# 1  1204524163      de       55129/2015            None  2015-04-29        0
# 2  1100343807      de       07450/1985       2P-343807  1985-12-05        1
# 3  1205989023      fr       01322/2019          732952  2019-06-27        1
# 4  1200001111      de       05028/1991        P-393027  1991-07-23        1
#
#                                               marque basregper  \
# 0  https://www.swissreg.ch/srclient/images/loadIm...        20
# 1  https://www.swissreg.ch/srclient/images/loadIm...        10
# 2  https://www.swissreg.ch/srclient/images/loadIm...        40
# 3  https://www.swissreg.ch/srclient/images/loadIm...        10
# 4  https://www.swissreg.ch/srclient/images/loadIm...        30
#
#   Échéance de la protection   Classes de Nice martype  \
# 0                2018-01-16              [33]       3
# 1                2025-04-29          [32, 33]       3
# 2                2025-12-05              [14]       3
# 3                2029-06-27      [35, 37, 39]       3
# 4                2021-07-23  [14, 16, 25, 28]       3
#
#                                            titulaire  \
# 0  DIWISA Distillerie Willisau SA Menznauerstrass...
# 1  Emil Ebneter & Co. AG Weissbadstrasse 27 9050 ...
# 2  APPLE INC. 1 Infinite Loop Cupertino, CA 95014 US
# 3  Apple Fresh / Individuelle Chemin de pré-desso...
# 4  McDonald's International Property Company, Ltd...
#
#                                           mandataire
# 0
# 1    Phaenomina GmbH Grundstrasse 60 B 8712 Stäfa CH
# 2  Lenz & Staehelin Brandschenkestrasse 24 8027 Z...
# 3  Polat Safak / Individuelle Chemin de pré-desso...
# 4      Isler & Pedrazzini AG Postfach 8027 Zürich CH

# %%
#analyse dataframe
df.shape
# Out:
# (28, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   basipikey           28 non-null     object
#  1   origlan             28 non-null     object
#  2   basappn             28 non-null     object
#  3   basregn             27 non-null     object
#  4   basannd             28 non-null     object
#  5   basstate            28 non-null     object
#  6   marpicn             28 non-null     object
#  7   basregper           28 non-null     object
#  8   expirationdate      28 non-null     object
#  9   classes             28 non-null     object
#  10  gstermt             28 non-null     object
#  11  titulaire_name      28 non-null     object
#  12  titulaire_addrl     28 non-null     object
#  13  titulaire_plainco   28 non-null     object
#  14  titulaire_nat       28 non-null     object
#  15  mandataire_namel    22 non-null     object
#  16  mandataire_addrl    22 non-null     object
#  17  mandataire_plainco  22 non-null     object
#  18  mandataire_nat      22 non-null     object
#  19  martype             28 non-null     object
# dtypes: object(20)
# memory usage: 4.5+ KB

# %%
df.columns
# Out:
# Index(['basipikey', 'origlan', 'basappn', 'basannd', 'basstate', 'basregper',
#        'expirationdate', 'marpicn', 'classes', 'gstermt', 'titulaire_name',
#        'titulaire_addrl', 'titulaire_plainco', 'titulaire_nat',
#        'mandataire_namel', 'mandataire_addrl', 'mandataire_plainco',
#        'mandataire_nat', 'martype'],
#       dtype='object')

# %%
#drop cols that will not be needed
df.drop(['origlan', 'basannd', 'basstate', 'basregper',
        'gstermt', 'mandataire_namel', 'mandataire_addrl', 'mandataire_plainco',
       'mandataire_nat', 'martype'], axis=1, inplace=True)

# %%
#verify new cols available
df.columns
# Out:
# Index(['basipikey', 'basappn', 'marpicn', 'classes', 'titulaire_name',
#        'titulaire_addrl', 'titulaire_plainco', 'titulaire_nat'],
#       dtype='object')

# %%
df.head()
# Out:
#     basipikey     basappn                                            marpicn  \
# 0  1100397439  07101/1992  https://www.swissreg.ch/srclient/images/loadIm...
# 1  1201896146  52821/2007  https://www.swissreg.ch/srclient/images/loadIm...
# 2  1100370951  01361/1989  https://www.swissreg.ch/srclient/images/loadIm...
# 3  1204108655  52937/2014  https://www.swissreg.ch/srclient/images/loadIm...
# 4  1204084228  51740/2014  https://www.swissreg.ch/srclient/images/loadIm...
#
#         classes                                     titulaire_name  \
# 0       [9, 16]                                   Bedag Informatik
# 1          [45]                  Thomas H.A. Verschuuren Kopfstein
# 2       [9, 14]  Universo (S.A.) Société Générale\ndes Fabrique...
# 3  [36, 41, 45]                              Manfred Stefan Harsch
# 4      [35, 45]                       ALLIANCE OF BUSINESS LAWYERS
#
#                         titulaire_addrl       titulaire_plainco titulaire_nat
# 0                  Engehaldenstrasse 12               3012 Bern            CH
# 1                     Badenerstrasse 97             8004 Zürich            CH
# 2             82, avenue Léopold-Robert  2300 La Chaux-de-Fonds            CH
# 3  Av. de Chailly 63b\nCase postale 157        1000 Lausanne 12            CH
# 4           c/o  Dunand Guth Mardam Bey             1206 Genève            CH

# %%
#merge address
df['address'] = df[['titulaire_name', 'titulaire_addrl', 'titulaire_plainco', 'titulaire_nat']].apply(lambda x: ' '.join(x), axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-64e0267186be> in <module>
#       1 #merge address
# ----> 2 df['address'] = df[['titulaire_name', 'titulaire_addrl', 'titulaire_plainco', 'titulaire_nat']].apply(lambda x: ' '.join(x), axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-29-64e0267186be> in <lambda>(x)
#       1 #merge address
# ----> 2 df['address'] = df[['titulaire_name', 'titulaire_addrl', 'titulaire_plainco', 'titulaire_nat']].apply(lambda x: ' '.join(x), axis=1)
#
# TypeError: sequence item 1: expected str instance, NoneType found

# %%
df.head()
# Out:
#     basipikey     basappn                                            marpicn  \
# 0  1100397439  07101/1992  https://www.swissreg.ch/srclient/images/loadIm...
# 1  1201896146  52821/2007  https://www.swissreg.ch/srclient/images/loadIm...
# 2  1100370951  01361/1989  https://www.swissreg.ch/srclient/images/loadIm...
# 3  1204108655  52937/2014  https://www.swissreg.ch/srclient/images/loadIm...
# 4  1204084228  51740/2014  https://www.swissreg.ch/srclient/images/loadIm...
#
#         classes                                     titulaire_name  \
# 0       [9, 16]                                   Bedag Informatik
# 1          [45]                  Thomas H.A. Verschuuren Kopfstein
# 2       [9, 14]  Universo (S.A.) Société Générale\ndes Fabrique...
# 3  [36, 41, 45]                              Manfred Stefan Harsch
# 4      [35, 45]                       ALLIANCE OF BUSINESS LAWYERS
#
#                         titulaire_addrl       titulaire_plainco titulaire_nat
# 0                  Engehaldenstrasse 12               3012 Bern            CH
# 1                     Badenerstrasse 97             8004 Zürich            CH
# 2             82, avenue Léopold-Robert  2300 La Chaux-de-Fonds            CH
# 3  Av. de Chailly 63b\nCase postale 157        1000 Lausanne 12            CH
# 4           c/o  Dunand Guth Mardam Bey             1206 Genève            CH

# %%
#drop unused columns 
df.drop(['titulaire_name','titulaire_addrl','titulaire_plainco','titulaire_nat'], axis=1, inplace=True)

# %%
pd.set_option('display.max_colwidth', None)

# %%
df.head(10)
# Out:
#     basipikey     basappn  \
# 0  1205675543  72090/2018
#
#                                                                                                                                                 marpicn  \
# 0  https://www.swissreg.ch/srclient/images/loadImage?Action=LoadImg&ItemType=tm&ImageType=print&ImageHash=B6C38363D3FB3B7BC1058DFAEC7EF133946F044B.jpeg
#
#         classes  \
# 0  [29, 30, 31]
#
#                                                                    address
# 0  Zweifel Chips + Snacks Holding AG Zweifelstrasse 5 8957 Spreitenbach CH

# %%
df['address'] =  df['address'].str.replace(r'\n', '')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#     basipikey     basappn  \
# 0  1205675543  72090/2018
#
#                                                                                                                                                 marpicn  \
# 0  https://www.swissreg.ch/srclient/images/loadImage?Action=LoadImg&ItemType=tm&ImageType=print&ImageHash=B6C38363D3FB3B7BC1058DFAEC7EF133946F044B.jpeg
#
#         classes  \
# 0  [29, 30, 31]
#
#                                                                    address
# 0  Zweifel Chips + Snacks Holding AG Zweifelstrasse 5 8957 Spreitenbach CH

# %%
df['classes'] = df['classes'].apply(lambda x: ','.join(map(str, x)))

# %%
df.head()
# Out:
#     basipikey     basappn  \
# 0  1205675543  72090/2018
#
#                                                                                                                                                 marpicn  \
# 0  https://www.swissreg.ch/srclient/images/loadImage?Action=LoadImg&ItemType=tm&ImageType=print&ImageHash=B6C38363D3FB3B7BC1058DFAEC7EF133946F044B.jpeg
#
#     classes  \
# 0  29,30,31
#
#                                                                    address
# 0  Zweifel Chips + Snacks Holding AG Zweifelstrasse 5 8957 Spreitenbach CH

# %%
#reorder column
column_names = ["marpicn", "basipikey", "basappn", "classes", "address"]


df = df.reindex(columns=column_names,)

# %%
df.head()
# Out:
#                                                                                                                                                 marpicn  \
# 0  https://www.swissreg.ch/srclient/images/loadImage?Action=LoadImg&ItemType=tm&ImageType=print&ImageHash=B6C38363D3FB3B7BC1058DFAEC7EF133946F044B.jpeg
#
#     basipikey     basappn   classes  \
# 0  1205675543  72090/2018  29,30,31
#
#                                                                    address
# 0  Zweifel Chips + Snacks Holding AG Zweifelstrasse 5 8957 Spreitenbach CH

# %%
#replace column names with appropriate column names
df['Marques'] = df['marpicn']
df['Déposant(e)'] = df['address']

# %%
#drop old names
df.drop(['marpicn', 'address'], axis=1, inplace=True)

# %%
#reorder column names
column_names = ["Marques", "basipikey", "basappn", "classes", "Déposant(e)"]


df = df.reindex(columns=column_names,)

# %%
df.head()
# Out:
#                                                                                                                                                 Marques  \
# 0  https://www.swissreg.ch/srclient/images/loadImage?Action=LoadImg&ItemType=tm&ImageType=print&ImageHash=B6C38363D3FB3B7BC1058DFAEC7EF133946F044B.jpeg
#
#     basipikey     basappn   classes  \
# 0  1205675543  72090/2018  29,30,31
#
#                                                                Déposant(e)
# 0  Zweifel Chips + Snacks Holding AG Zweifelstrasse 5 8957 Spreitenbach CH

# %%
#display trademark logo in dataframe
from IPython.core.display import HTML
def to_img_tag(path):
    return '<img src="'+ path + '" width="50"  >'

# %%
display(HTML(df.to_html(escape=False,formatters=dict(Marques=to_img_tag))))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Marques</th>
#       <th>basipikey</th>
#       <th>basappn</th>
#       <th>classes</th>
#       <th>Déposant(e)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="https://www.swissreg.ch/srclient/images/loadImage?Action=LoadImg&ItemType=tm&ImageType=print&ImageHash=B6C38363D3FB3B7BC1058DFAEC7EF133946F044B.jpeg" width="50"  ></td>
#       <td>1205675543</td>
#       <td>72090/2018</td>
#       <td>29,30,31</td>
#       <td>Zweifel Chips + Snacks Holding AG Zweifelstrasse 5 8957 Spreitenbach CH</td>
#     </tr>
#   </tbody>
# </table>
